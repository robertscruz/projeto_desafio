# %%
import pandas as pd

# %%
import csv

with open("entregas_tab.txt", newline='') as f:
     f = (linha.strip('|') for linha in f if '---' not in linha) 
     cf = csv.DictReader(f, delimiter='|')
     df_entregas = pd.DataFrame(cf)

# %%
df_entregas
# Out:
#    NÂº de ocorrÃªncias                                                        9  \
# 0   NÂº mÃ¡ximo entradas                          ...
# 1                       Tempo de execuÃ§Ã£o  00:00:43
# 2                                             SKU.
# 3                                             100312
# 4                                             89721
# 5                                             192063
# 6                                             182285
# 7                                             32934
# 8                                             43495
# 9                                             4342
# 10                                            3124
# 11                                            43495
#
#                                 NaN
# 0                               NaN
# 1                               NaN
# 2   [DT.Compra, Dt.Chegada, SKTD, ]
# 3   [20171202 , 20180105  ,  27 , ]
# 4   [20171202 , 20180105  ,  26 , ]
# ...

# %%
prods = pd.read_csv("prods_tab.csv", encoding='latin-1', sep=',')
#Remove valores duplicados
prods = df_prods.drop_duplicates()
prods.dropna(how='all', inplace=True)
#Para remover todos os valores faltantes ou nulos: "df_prods.dropna(inplace=True)"

prods.drop(5)
# Out:
#      ID. Forn.                                        Prod. DESC.        SKU.  \
# 1    302100012  GELADEIRA FROST FREE INVERTER IB53X ELECTROLUX...     100312-
# 2    302100012  GELADEIRA FROST FREE DB84 ELECTROLUX 598 LITRO...    89 721 ?
# 3    302100012  Frigobar Electrolux RE80 79 Litros Classe A 11...  ?1920-- 63
# 6    302100012  Geladeira Electrolux SS72X Side by Side Frost ...     18228 5
# 10  9009101002  Smartphone Apple iPhone XS 256GB 4G Tela 5,8""...      32 934
# 11  9030121093  SMARTPHONE SAMSUNG GALAXY NOTE 8 N950F 64GB 2C...    4??349 5
# 12   320621093    BONECA MULTIKIDS BUSH BABY WORLD SHIMMIES BR106       4342I
# 13   320621093  Brinquedo Kit de Voley Disney Princesas Líder ...   3 1---24-
# 14  9030121093  SMARTPHONE SAMSUNG GALAXY A8+ A730 64GB 2CHIPS...    1 92501
#
#    GRP. MERC. 3 COD. MARC.
# 1           996        302
# 2           NaN        NaN
# 3           996        302
# 6           996        302
# 10          102        401
# ...

# %%
df_novo = pd.concat([df_entregas, df_prods])
pd.concat([df_entregas, df_prods], axis=1)

df_novo.drop([0,1])
# Out:
# c:\users\bob\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    NÂº de ocorrÃªncias                                                        9  \
# 2                                             SKU.
# 3                                             100312
# 4                                             89721
# 5                                             192063
# 6                                             182285
# 7                                             32934
# 8                                             43495
# 9                                             4342
# 10                                            3124
# ...
